# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import math

# %%
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
import random

# %%
import tldextract

# %%
from urllib.parse import urlparse

# %%
from scipy.stats import randint, uniform,entropy

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV

# %%
from xgboost import XGBClassifier

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score,accuracy_score

# %%
from tqdm import tqdm

# %%
import optuna

# %%
from collections import Counter

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
new_df = pd.DataFrame()

# %%
ttld_df = pd.DataFrame()

# %%
special_chars = set()

# %%
ip_pattern = r'[0-9]+(?:\.[0-9]+){3}'

# %%
sus_words = ['secure', 'account', 'update', 'login', 'verify' ,'signin', 'bank',
            'notify', 'click', 'inconvenient']

# %%
def find_special_char(x):
    special_chars_in_x = re.findall(r'[^a-zA-Z0-9]', x)
    special_chars.update(special_chars_in_x)
    return None

# %%
def urlentropy(url):
    frequencies = Counter(url)
    prob = [frequencies[char] / len(url) for char in url]
    return entropy(prob, base=2)

# %%
def redirection(url):
  pos = url.rfind('//') 
  return pos>7

# %%
url_df = pd.read_csv('Dataset/dataset_urls.csv')

# %%
url_df['URL'].str.strip()
# Out:
# 0         nobell.it/70ffb52d079109dca5664cce6f317373782/...
# 1         www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...
# 2         serviciosbys.com/paypal.cgi.bin.get-into.herf....
# 3         mail.printakid.com/www.online.americanexpress....
# 4         thewhiskeydregs.com/wp-content/themes/widescre...
#                                 ...
# 549341                                      23.227.196.215/
# 549342                                   apple-checker.org/
# 549343                                    apple-iclods.org/
# 549344                                   apple-uptoday.org/
# 549345                                    apple-search.info
# Name: URL, Length: 549346, dtype: object

# %%
url_df
# Out:
#                                                       URL Label
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3       mail.printakid.com/www.online.americanexpress....   bad
# 4       thewhiskeydregs.com/wp-content/themes/widescre...   bad
# ...                                                   ...   ...
# 549341                                    23.227.196.215/   bad
# 549342                                 apple-checker.org/   bad
# 549343                                  apple-iclods.org/   bad
# 549344                                 apple-uptoday.org/   bad
# 549345                                  apple-search.info   bad
#
# [549346 rows x 2 columns]

# %%
url_df.head()
# Out:
#                                                  URL Label
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3  mail.printakid.com/www.online.americanexpress....   bad
# 4  thewhiskeydregs.com/wp-content/themes/widescre...   bad

# %%
url_df.sample(11)
# Out:
#                                                       URL Label
# 100269                 geocrestenergy.com/rrts_cancel.htm   bad
# 122530  raphaelalvespilates.com.br/wp-content/plugins/...   bad
# 200137                indexgwm.homestead.com/GWMcRae.html  good
# 404067  newswire.ca/en/story/160497/support-for-future...  good
# 164644                       dialup.pacbell.net/help.html  good
# 265828  4shared.com/audio/mvWRbksB/Adam_Tas_feat_Sophe...  good
# 541705                            toldronher.com/gate.php   bad
# 393319              mp3raid.com/music/michael_franti.html  good
# 394334                     music-story.com/plan-du-site-E  good
# 75562                     sourceforge.net/projects/barat/  good
# 352092                 hitmastersports.com/dodgeball.html  good

# %%
url_df_bad = url_df[url_df['Label'] == 'bad']

# %%
url_df_bad['URL'].apply(find_special_char)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 549341    None
# 549342    None
# 549343    None
# 549344    None
# 549345    None
# Name: URL, Length: 156422, dtype: object

# %%
special_chars = list(special_chars)

# %%
special_chars.remove('.')

# %%
special_chars.remove('/')

# %%
new_df['Special Character'] = special_chars

# %%
new_df['Frequency in bad URLs'] = new_df['Special Character'].apply(lambda x: url_df_bad[url_df_bad['URL'].str.contains(re.escape(x), regex=True)].shape[0])

# %%
new_df['Bad probability'] = new_df['Frequency in bad URLs']/new_df['Special Character'].apply(lambda x: url_df[url_df['URL'].str.contains(re.escape(x), regex=True)].shape[0])

# %%
new_df['Score'] = new_df['Bad probability']*new_df['Frequency in bad URLs'].apply(math.log)

# %%
new_df.sort_values(by='Score', ignore_index=True, ascending=False, inplace=True)

# %%
new_df
# Out:
#     Special Character  Frequency in bad URLs  Bad probability     Score
# 0                   \                   6363         0.966874  8.468132
# 1                   ;                  11294         0.906639  8.460778
# 2                                       1066         0.955197  6.659318
# 3                   @                   1809         0.882870  6.621990
# 4                   '                   3591         0.774089  6.336839
# ..                ...                    ...              ...       ...
# 167                 Ö                      1         0.031250  0.000000
# 168                                       1         0.050000  0.000000
# 169                                       1         0.041667  0.000000
# 170                 °                      1         0.037037  0.000000
# 171                 Ý                      1         0.034483  0.000000
#
# [172 rows x 4 columns]

# %%
dangerous_chars = list(new_df['Special Character'].head(10))

# %%
print(dangerous_chars)
# Out:
# ['\\', ';', ' ', '@', "'", ':', '&', '>', '<', '=']

# %%
plt.bar(new_df['Special Character'].head(10), new_df['Score'].head(10), color = 'cyan')
plt.xlabel('Special Character')
plt.ylabel('Score')
plt.show()

# %%
ttld_list = pd.Series(url_df_bad['URL'].apply(lambda x: tldextract.extract(x).suffix)).unique()

# %%
ttld_df['ttld'] = ttld_list

# %%
ttld_df['Frequency in bad URLs'] = ttld_df['ttld'].apply(lambda x: url_df_bad[url_df_bad['URL'].str.contains(re.escape(x), regex=True)].shape[0])

# %%
ttld_df['Bad probability'] = ttld_df['Frequency in bad URLs']/ttld_df['ttld'].apply(lambda x: url_df[url_df['URL'].str.contains(re.escape(x), regex=True)].shape[0])

# %%
ttld_df['Score'] = ttld_df['Bad probability']*ttld_df['Frequency in bad URLs'].apply(math.log)

# %%
ttld_df.sort_values(by='Score', ignore_index=True, ascending=False, inplace=True)

# %%
ttld_df
# Out:
#           ttld  Frequency in bad URLs  Bad probability     Score
# 0       com.br                   4235         0.982599  8.205817
# 1           mx                   3698         0.931486  7.652669
# 2           cm                  10508         0.812495  7.523618
# 3           bf                   3900         0.878576  7.264711
# 4         date                   5402         0.775258  6.662977
# ..         ...                    ...              ...       ...
# 601     com.bb                      1         1.000000  0.000000
# 602  sa.edu.au                      1         0.142857  0.000000
# 603     gob.do                      1         1.000000  0.000000
# 604     edu.bt                      1         1.000000  0.000000
# 605    info.ro                      1         1.000000  0.000000
#
# [606 rows x 4 columns]

# %%
dangerous_ttlds = list(ttld_df['ttld'].head(10))

# %%
print(dangerous_ttlds)
# Out:
# ['com.br', 'mx', 'cm', 'bf', 'date', 'run', 'xyz', 'mg', 'com.ar', 'ph']

# %%
plt.bar(ttld_df['ttld'].head(10), ttld_df['Score'].head(10), color = 'darkred')
plt.xlabel('Dangerous ttld')
plt.ylabel('Score')
plt.show()

# %%
url_df['URL length'] = url_df['URL'].apply(len)

# %%
url_df['Number of dots'] = url_df['URL'].apply(lambda x: x.count('.'))

# %%
url_df['Number of slashes'] = url_df['URL'].apply(lambda x: x.count('/'))

# %%
url_df['Percentage of numerical characters'] = url_df['URL'].apply(lambda x: sum(c.isdigit() for c in x))/url_df['URL length']

# %%
url_df['Dangerous characters'] = url_df['URL'].apply(lambda x: any(char in x for char in dangerous_chars))

# %%
url_df['Dangerous ttld'] = url_df['URL'].apply(lambda x: tldextract.extract(x).suffix in dangerous_ttlds)

# %%
url_df['Entropy'] = url_df['URL'].apply(urlentropy)

# %%
url_df['IP Address'] = url_df['URL'].apply(lambda x: bool(re.search(ip_pattern, x)))

# %%
url_df['Domain name length'] = url_df['URL'].apply(lambda x: len(tldextract.extract(x).domain))

# %%
url_df['Suspicious keywords'] = url_df['URL'].apply(lambda x: sum([word in x for word in sus_words]) != 0)

# %%
url_df['Repetitions'] = url_df['URL'].apply(lambda x: True if re.search(r'(.)\1{2,}', tldextract.extract(x).domain) else False)

# %%
url_df['Redirections'] = url_df['URL'].apply(redirection)

# %%
url_df.head()
# Out:
#                                                  URL Label  URL length  \
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad         225
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad          81
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad         177
# 3  mail.printakid.com/www.online.americanexpress....   bad          60
# 4  thewhiskeydregs.com/wp-content/themes/widescre...   bad         116
#
#    Number of dots  Number of slashes  Percentage of numerical characters  \
# 0               6                 10                            0.257778
# 1               5                  4                            0.012346
# 2               7                 11                            0.265537
# 3               6                  2                            0.000000
# 4               1                 10                            0.181034
#
#    Dangerous characters  Dangerous ttld   Entropy  IP Address  \
# 0                  True           False  7.667575       False
# 1                  True           False  6.190289       False
# 2                 False           False  7.288285       False
# 3                 False           False  5.786667       False
# 4                 False           False  6.611978       False
#
#    Domain name length  Suspicious keywords  Repetitions  Redirections
# 0                   6                 True        False         False
# 1                   7                False        False         False
# 2                  12                 True        False         False
# 3                   9                False        False         False
# 4                  15                False        False          True

# %%
scaler = MinMaxScaler()

# %%
num_columns = ['URL length', 'Number of dots', 'Number of slashes', 'Domain name length', 'Entropy']

# %%
url_df[num_columns] = scaler.fit_transform(url_df[num_columns])

# %%
url_df['IP Address'] = url_df['IP Address'].astype(int)

# %%
url_df['Suspicious keywords'] = url_df['Suspicious keywords'].astype(int)

# %%
url_df['Repetitions'] = url_df['Repetitions'].astype(int)

# %%
url_df['Redirections'] = url_df['Redirections'].astype(int)

# %%
url_df['Dangerous characters'] = url_df['Dangerous characters'].astype(int)

# %%
url_df['Dangerous ttld'] = url_df['Dangerous ttld'].astype(int)

# %%
url_df['Label'] = (url_df['Label'] == 'good').astype(int)

# %%
url_df.drop(columns=['URL'], inplace=True)

# %%
url_df
# Out:
#         Label  URL length  Number of dots  Number of slashes  \
# 0           0    0.097138        0.162162           0.285714
# 1           0    0.034692        0.135135           0.114286
# 2           0    0.076323        0.189189           0.314286
# 3           0    0.025585        0.162162           0.057143
# 4           0    0.049870        0.027027           0.285714
# ...       ...         ...             ...                ...
# 549341      0    0.006071        0.081081           0.028571
# 549342      0    0.007372        0.027027           0.028571
# 549343      0    0.006938        0.027027           0.028571
# 549344      0    0.007372        0.027027           0.028571
# 549345      0    0.006938        0.027027           0.000000
#
#         Percentage of numerical characters  Dangerous characters  \
# 0                                 0.257778                     1
# 1                                 0.012346                     1
# 2                                 0.265537                     0
# 3                                 0.000000                     0
# 4                                 0.181034                     0
# ...                                    ...                   ...
# 549341                            0.733333                     0
# 549342                            0.000000                     0
# 549343                            0.000000                     0
# 549344                            0.000000                     0
# 549345                            0.000000                     0
#
#         Dangerous ttld   Entropy  IP Address  Domain name length  \
# 0                    0  0.688511           0            0.039735
# 1                    0  0.555858           0            0.046358
# 2                    0  0.654453           0            0.079470
# 3                    0  0.519615           0            0.059603
# 4                    0  0.593724           0            0.099338
# ...                ...       ...         ...                 ...
# 549341               0  0.331627           1            0.092715
# 549342               0  0.362000           0            0.086093
# 549343               0  0.359344           0            0.079470
# 549344               0  0.360275           0            0.086093
# 549345               0  0.359344           0            0.079470
#
#         Suspicious keywords  Repetitions  Redirections
# 0                         1            0             0
# 1                         0            0             0
# 2                         1            0             0
# 3                         0            0             0
# 4                         0            0             1
# ...                     ...          ...           ...
# 549341                    0            0             0
# 549342                    0            0             0
# 549343                    0            0             0
# 549344                    0            0             0
# 549345                    0            0             0
#
# [549346 rows x 13 columns]

# %%
corr_matrix = url_df.corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 6})
plt.show()
sns.heatmap(corr_matrix[['Label']].sort_values(by='Label').T, annot=True, cmap='coolwarm', linewidths=0.5, annot_kws={"size": 8})
plt.show()

# %%
print(corr_matrix[['Label']].sort_values(by='Label'))
# Out:
#                                        Label
# Suspicious keywords                -0.360325
# Number of dots                     -0.293474
# Percentage of numerical characters -0.204039
# IP Address                         -0.191832
# URL length                         -0.177295
# Dangerous ttld                     -0.163621
# Dangerous characters               -0.146440
# Domain name length                 -0.144416
# Number of slashes                  -0.118405
# Entropy                            -0.096089
# Redirections                       -0.088167
# Repetitions                        -0.049215
# Label                               1.000000

# %%
pca = PCA(n_components=1)

# %%
url_df['Entropy and length (PCA)'] = pca.fit_transform(url_df[['Entropy', 'URL length']])

# %%
url_df.drop(columns=['Entropy', 'URL length'], inplace=True)

# %%
url_df
# Out:
#         Label  Number of dots  Number of slashes  \
# 0           0        0.162162           0.285714
# 1           0        0.135135           0.114286
# 2           0        0.189189           0.314286
# 3           0        0.162162           0.057143
# 4           0        0.027027           0.285714
# ...       ...             ...                ...
# 549341      0        0.081081           0.028571
# 549342      0        0.027027           0.028571
# 549343      0        0.027027           0.028571
# 549344      0        0.027027           0.028571
# 549345      0        0.027027           0.000000
#
#         Percentage of numerical characters  Dangerous characters  \
# 0                                 0.257778                     1
# 1                                 0.012346                     1
# 2                                 0.265537                     0
# 3                                 0.000000                     0
# 4                                 0.181034                     0
# ...                                    ...                   ...
# 549341                            0.733333                     0
# 549342                            0.000000                     0
# 549343                            0.000000                     0
# 549344                            0.000000                     0
# 549345                            0.000000                     0
#
#         Dangerous ttld  IP Address  Domain name length  Suspicious keywords  \
# 0                    0           0            0.039735                    1
# 1                    0           0            0.046358                    0
# 2                    0           0            0.079470                    1
# 3                    0           0            0.059603                    0
# 4                    0           0            0.099338                    0
# ...                ...         ...                 ...                  ...
# 549341               0           1            0.092715                    0
# 549342               0           0            0.086093                    0
# 549343               0           0            0.079470                    0
# 549344               0           0            0.086093                    0
# 549345               0           0            0.079470                    0
#
#         Repetitions  Redirections  Entropy and length (PCA)
# 0                 0             0                  0.231828
# 1                 0             0                  0.088713
# 2                 0             0                  0.194035
# 3                 0             0                  0.051355
# 4                 0             1                  0.128985
# ...             ...           ...                       ...
# 549341            0             0                 -0.136338
# 549342            0             0                 -0.106419
# 549343            0             0                 -0.109105
# 549344            0             0                 -0.108102
# 549345            0             0                 -0.109105
#
# [549346 rows x 12 columns]

# %%
url_df['Label'].value_counts(normalize=True)
# Out:
# Label
# 1    0.715258
# 0    0.284742
# Name: proportion, dtype: float64

# %%
n_samples = url_df['Label'].value_counts()[0]

# %%
url_df_good = url_df[url_df['Label'] == 1]

# %%
url_df_bad = url_df[url_df['Label'] == 0]

# %%
url_df_goodsample = url_df_good.sample(n=n_samples, random_state=22)

# %%
url_df_goodmissing = url_df_good.drop(url_df_goodsample.index)

# %%
url_df = pd.concat([url_df_bad, url_df_goodsample], ignore_index=True)

# %%
url_df
# Out:
#         Label  Number of dots  Number of slashes  \
# 0           0        0.162162           0.285714
# 1           0        0.135135           0.114286
# 2           0        0.189189           0.314286
# 3           0        0.162162           0.057143
# 4           0        0.027027           0.285714
# ...       ...             ...                ...
# 312839      1        0.027027           0.028571
# 312840      1        0.054054           0.057143
# 312841      1        0.054054           0.085714
# 312842      1        0.054054           0.028571
# 312843      1        0.027027           0.114286
#
#         Percentage of numerical characters  Dangerous characters  \
# 0                                 0.257778                     1
# 1                                 0.012346                     1
# 2                                 0.265537                     0
# 3                                 0.000000                     0
# 4                                 0.181034                     0
# ...                                    ...                   ...
# 312839                            0.000000                     0
# 312840                            0.000000                     0
# 312841                            0.000000                     0
# 312842                            0.000000                     0
# 312843                            0.000000                     0
#
#         Dangerous ttld  IP Address  Domain name length  Suspicious keywords  \
# 0                    0           0            0.039735                    1
# 1                    0           0            0.046358                    0
# 2                    0           0            0.079470                    1
# 3                    0           0            0.059603                    0
# 4                    0           0            0.099338                    0
# ...                ...         ...                 ...                  ...
# 312839               0           0            0.046358                    0
# 312840               0           0            0.059603                    0
# 312841               0           0            0.019868                    0
# 312842               0           0            0.052980                    0
# 312843               0           0            0.052980                    0
#
#         Repetitions  Redirections  Entropy and length (PCA)
# 0                 0             0                  0.231828
# 1                 0             0                  0.088713
# 2                 0             0                  0.194035
# 3                 0             0                  0.051355
# 4                 0             1                  0.128985
# ...             ...           ...                       ...
# 312839            0             0                 -0.039679
# 312840            0             0                 -0.060949
# 312841            0             0                 -0.017980
# 312842            0             0                 -0.007196
# 312843            0             0                 -0.046881
#
# [312844 rows x 12 columns]

# %%
y = url_df['Label']

# %%
url_df.drop(columns=['Label'], inplace=True)

# %%
url_df_train, url_df_test, y_train, y_test = train_test_split(url_df, y, test_size=0.2, random_state=22)

# %%
y_goodmissing = url_df_goodmissing['Label']

# %%
url_df_goodmissing.drop(columns=['Label'], inplace=True)

# %%
url_df_test = pd.concat([url_df_test, url_df_goodmissing], axis=0)

# %%
y_test = pd.concat([y_test, y_goodmissing], axis=0)

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=22)

# %%
xgb_model = XGBClassifier(random_state=22)

# %%
print(cross_val_score(xgb_model, url_df_train, y_train, cv=kf, scoring='accuracy').mean())
# Out:
# 0.8382259514534013

# %%
rf_model = RandomForestClassifier(random_state=22)

# %%
print(cross_val_score(rf_model, url_df_train, y_train, cv=kf, scoring='accuracy').mean())
# Out:
# 0.8595864548996105

# %%
rf_model.fit(url_df_train, y_train)
# Out:
# RandomForestClassifier(random_state=22)

# %%
importances = rf_model.feature_importances_

# %%
feature_names = url_df.columns

# %%
indices = np.argsort(importances)[::-1]

# %%
plt.title('Feature Importance (RandomForestClassifier)')
plt.bar(range(url_df.shape[1]), importances[indices], align='center', color="blue")
plt.xticks(range(url_df.shape[1]), feature_names[indices], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.show()

# %%
xgb_model.fit(url_df_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=22, ...)

# %%
importances = xgb_model.feature_importances_

# %%
feature_names = url_df.columns

# %%
indices = np.argsort(importances)[::-1]

# %%
plt.title('Feature Importance (url_dfGBClassifier)')
plt.bar(range(url_df.shape[1]), importances[indices], align='center')
plt.xticks(range(url_df.shape[1]), feature_names[indices], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.show()

# %%
rf_pred = rf_model.predict(url_df_test)

# %%
xgb_pred = xgb_model.predict(url_df_test)

# %%
print(accuracy_score(y_test, rf_pred))
# Out:
# 0.8634270791885539

# %%
print(accuracy_score(y_test, xgb_pred))
# Out:
# 0.8644000922857783

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 400)
    max_depth = trial.suggest_int('max_depth', 3, 7)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 0.3)
    subsample = trial.suggest_uniform('subsample', 0.6, 1.0)
    reg_alpha = trial.suggest_loguniform('reg_alpha', 1e-3, 10.0)
    model = XGBClassifier(
        random_state=22,
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        reg_alpha=reg_alpha,
        use_label_encoder=False,
        eval_metric='mlogloss'
    )

    
    mean_score = cross_val_score(model, url_df, y, cv=kf, scoring='accuracy').mean()
    return mean_score

# %%
study = optuna.create_study(direction='maximize')
# Out:
# [I 2025-04-05 22:39:05,611] A new study created in memory with name: no-name-6513df42-0f26-4941-bb46-de0826cd6685

# %%
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-04-05 22:39:35,273] Trial 0 finished with value: 0.7176260286901842 and parameters: {'n_estimators': 252, 'max_depth': 4, 'learning_rate': 0.0011445008205339447, 'subsample': 0.8566816002264146, 'reg_alpha': 9.557058499341714}. Best is trial 0 with value: 0.7176260286901842.
# [I 2025-04-05 22:40:33,660] Trial 1 finished with value: 0.7608872113636433 and parameters: {'n_estimators': 390, 'max_depth': 5, 'learning_rate': 0.0032242103056723628, 'subsample': 0.6141344647359905, 'reg_alpha': 0.001471795975442811}. Best is trial 1 with value: 0.7608872113636433.
# [I 2025-04-05 22:41:26,611] Trial 2 finished with value: 0.837788160222503 and parameters: {'n_estimators': 341, 'max_depth': 5, 'learning_rate': 0.12975422799469788, 'subsample': 0.8008732491438832, 'reg_alpha': 3.43937349676784}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:42:16,160] Trial 3 finished with value: 0.7286954471671149 and parameters: {'n_estimators': 398, 'max_depth': 4, 'learning_rate': 0.0019865450714375123, 'subsample': 0.921045021102848, 'reg_alpha': 0.012237126748060418}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:42:54,045] Trial 4 finished with value: 0.7639174736563755 and parameters: {'n_estimators': 259, 'max_depth': 5, 'learning_rate': 0.0056509368520485225, 'subsample': 0.7157560785122162, 'reg_alpha': 4.2288844735619}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:43:23,020] Trial 5 finished with value: 0.7312749960004575 and parameters: {'n_estimators': 293, 'max_depth': 3, 'learning_rate': 0.007294878944007356, 'subsample': 0.6178730056018265, 'reg_alpha': 0.20288957495311263}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:43:46,605] Trial 6 finished with value: 0.7767097930068827 and parameters: {'n_estimators': 135, 'max_depth': 6, 'learning_rate': 0.011092545213838916, 'subsample': 0.684551208072842, 'reg_alpha': 0.007180232432739803}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:44:32,810] Trial 7 finished with value: 0.7526690566194004 and parameters: {'n_estimators': 383, 'max_depth': 4, 'learning_rate': 0.006952482000371276, 'subsample': 0.982093782005049, 'reg_alpha': 0.00563570990351113}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:44:52,246] Trial 8 finished with value: 0.7172744187292048 and parameters: {'n_estimators': 212, 'max_depth': 3, 'learning_rate': 0.004447691288625006, 'subsample': 0.6340571115387094, 'reg_alpha': 0.17227595652587027}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:45:19,940] Trial 9 finished with value: 0.6720921605236105 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.0011847461932107907, 'subsample': 0.9598801142603877, 'reg_alpha': 0.3575779731845601}. Best is trial 2 with value: 0.837788160222503.
# [I 2025-04-05 22:46:23,537] Trial 10 finished with value: 0.8514563160455042 and parameters: {'n_estimators': 326, 'max_depth': 7, 'learning_rate': 0.20341101173762857, 'subsample': 0.7943478357364054, 'reg_alpha': 1.123861677612688}. Best is trial 10 with value: 0.8514563160455042.
# [I 2025-04-05 22:47:29,920] Trial 11 finished with value: 0.8516257293609847 and parameters: {'n_estimators': 333, 'max_depth': 7, 'learning_rate': 0.2249028242319914, 'subsample': 0.7886099060650946, 'reg_alpha': 1.5592752599324473}. Best is trial 11 with value: 0.8516257293609847.
# [I 2025-04-05 22:48:34,799] Trial 12 finished with value: 0.8520157012971015 and parameters: {'n_estimators': 328, 'max_depth': 7, 'learning_rate': 0.2950145231558448, 'subsample': 0.7657652237101132, 'reg_alpha': 1.114157696958106}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:49:10,903] Trial 13 finished with value: 0.8336295393006884 and parameters: {'n_estimators': 194, 'max_depth': 7, 'learning_rate': 0.0563375500464487, 'subsample': 0.7703608368952772, 'reg_alpha': 0.9938031743556881}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:50:08,110] Trial 14 finished with value: 0.830519360857484 and parameters: {'n_estimators': 349, 'max_depth': 6, 'learning_rate': 0.04068646199673245, 'subsample': 0.8693311854926961, 'reg_alpha': 0.970909108321448}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:51:00,232] Trial 15 finished with value: 0.85140517153731 and parameters: {'n_estimators': 297, 'max_depth': 7, 'learning_rate': 0.265394224304265, 'subsample': 0.7348744860895953, 'reg_alpha': 0.06628606108316472}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:51:53,387] Trial 16 finished with value: 0.8405243515781308 and parameters: {'n_estimators': 342, 'max_depth': 6, 'learning_rate': 0.09965811251893286, 'subsample': 0.8474270467448928, 'reg_alpha': 0.05760925421597187}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:52:15,795] Trial 17 finished with value: 0.8007217618288535 and parameters: {'n_estimators': 124, 'max_depth': 7, 'learning_rate': 0.024002136617426867, 'subsample': 0.6770154373397437, 'reg_alpha': 2.718126771566556}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:52:49,419] Trial 18 finished with value: 0.8365447284807036 and parameters: {'n_estimators': 216, 'max_depth': 6, 'learning_rate': 0.09529867411573162, 'subsample': 0.7502009399642621, 'reg_alpha': 0.5326639069297117}. Best is trial 12 with value: 0.8520157012971015.
# [I 2025-04-05 22:53:55,076] Trial 19 finished with value: 0.8521211829428211 and parameters: {'n_estimators': 364, 'max_depth': 7, 'learning_rate': 0.29433983460982266, 'subsample': 0.8129077107617415, 'reg_alpha': 0.03618791690322944}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 22:54:55,303] Trial 20 finished with value: 0.832638630175263 and parameters: {'n_estimators': 368, 'max_depth': 6, 'learning_rate': 0.048157157962163154, 'subsample': 0.9015058140021288, 'reg_alpha': 0.02795671141306855}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 22:55:53,634] Trial 21 finished with value: 0.8516672844252385 and parameters: {'n_estimators': 316, 'max_depth': 7, 'learning_rate': 0.285727964007099, 'subsample': 0.8063460810108997, 'reg_alpha': 0.022211553080438474}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 22:58:42,832] Trial 22 finished with value: 0.8516225324709726 and parameters: {'n_estimators': 312, 'max_depth': 7, 'learning_rate': 0.29408521811853017, 'subsample': 0.8342921725883687, 'reg_alpha': 0.02478682366453536}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 22:59:41,350] Trial 23 finished with value: 0.846719129145069 and parameters: {'n_estimators': 273, 'max_depth': 7, 'learning_rate': 0.15016607565319381, 'subsample': 0.815015810408665, 'reg_alpha': 0.0021581766813150295}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:00:47,185] Trial 24 finished with value: 0.8394023847673197 and parameters: {'n_estimators': 366, 'max_depth': 6, 'learning_rate': 0.08103526045647616, 'subsample': 0.885119067240291, 'reg_alpha': 0.0253874747125842}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:01:59,126] Trial 25 finished with value: 0.8492379571148435 and parameters: {'n_estimators': 363, 'max_depth': 7, 'learning_rate': 0.14942147536660674, 'subsample': 0.7597553909632171, 'reg_alpha': 0.003110466181565076}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:02:47,654] Trial 26 finished with value: 0.8214573373760751 and parameters: {'n_estimators': 273, 'max_depth': 6, 'learning_rate': 0.02873123591905818, 'subsample': 0.7035024040217501, 'reg_alpha': 0.11202211464051728}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:03:46,145] Trial 27 finished with value: 0.8486114448667451 and parameters: {'n_estimators': 283, 'max_depth': 7, 'learning_rate': 0.1828632954055833, 'subsample': 0.8242402724717294, 'reg_alpha': 0.04836031796633355}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:04:44,343] Trial 28 finished with value: 0.8366949656057128 and parameters: {'n_estimators': 315, 'max_depth': 6, 'learning_rate': 0.0782235090099156, 'subsample': 0.9315888393998354, 'reg_alpha': 0.010618865025413735}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:05:31,244] Trial 29 finished with value: 0.8499571669123333 and parameters: {'n_estimators': 226, 'max_depth': 7, 'learning_rate': 0.27315991776995635, 'subsample': 0.7787698721437306, 'reg_alpha': 0.35338606488026986}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:06:10,257] Trial 30 finished with value: 0.7810090603530186 and parameters: {'n_estimators': 244, 'max_depth': 5, 'learning_rate': 0.013789748694207946, 'subsample': 0.8581426728957114, 'reg_alpha': 0.10350108158942713}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:07:22,342] Trial 31 finished with value: 0.8495512111392047 and parameters: {'n_estimators': 329, 'max_depth': 7, 'learning_rate': 0.20804708716530432, 'subsample': 0.7946662485082192, 'reg_alpha': 7.79232051560047}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:08:37,348] Trial 32 finished with value: 0.8483013872113053 and parameters: {'n_estimators': 378, 'max_depth': 7, 'learning_rate': 0.12287000746444372, 'subsample': 0.7343692341699686, 'reg_alpha': 2.0412905607912695}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:09:48,862] Trial 33 finished with value: 0.8506987492998676 and parameters: {'n_estimators': 354, 'max_depth': 7, 'learning_rate': 0.29302955644841366, 'subsample': 0.8151856158452447, 'reg_alpha': 9.27843306920097}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:10:50,778] Trial 34 finished with value: 0.8501329737932705 and parameters: {'n_estimators': 332, 'max_depth': 7, 'learning_rate': 0.18947113272013225, 'subsample': 0.786989263121625, 'reg_alpha': 0.014652302676982532}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:11:36,231] Trial 35 finished with value: 0.836436049362577 and parameters: {'n_estimators': 313, 'max_depth': 5, 'learning_rate': 0.12661207257865614, 'subsample': 0.8403653903290782, 'reg_alpha': 5.122313753315726}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:12:42,824] Trial 36 finished with value: 0.8388909448962812 and parameters: {'n_estimators': 394, 'max_depth': 6, 'learning_rate': 0.06461282195449758, 'subsample': 0.7440629521624148, 'reg_alpha': 1.7350505870645254}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:13:16,352] Trial 37 finished with value: 0.8457729713915144 and parameters: {'n_estimators': 165, 'max_depth': 7, 'learning_rate': 0.2149769710338471, 'subsample': 0.8089627575740366, 'reg_alpha': 0.46588020886555725}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:13:44,961] Trial 38 finished with value: 0.8262105068567743 and parameters: {'n_estimators': 250, 'max_depth': 4, 'learning_rate': 0.12002426189834078, 'subsample': 0.7040601256985783, 'reg_alpha': 0.2053410866507586}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:14:34,357] Trial 39 finished with value: 0.8398978388395943 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.16440330010452256, 'subsample': 0.7653565199999027, 'reg_alpha': 0.0419164666366503}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:15:39,191] Trial 40 finished with value: 0.7695145168092742 and parameters: {'n_estimators': 379, 'max_depth': 6, 'learning_rate': 0.002641817639279854, 'subsample': 0.8777751449287822, 'reg_alpha': 0.00610404691128623}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:16:36,683] Trial 41 finished with value: 0.85074669691805 and parameters: {'n_estimators': 306, 'max_depth': 7, 'learning_rate': 0.26724000266463804, 'subsample': 0.838585114151144, 'reg_alpha': 0.023732200108452856}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:17:39,812] Trial 42 finished with value: 0.8512197771128799 and parameters: {'n_estimators': 318, 'max_depth': 7, 'learning_rate': 0.27857246307088446, 'subsample': 0.8242230434423751, 'reg_alpha': 0.015506694942859297}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:18:41,656] Trial 43 finished with value: 0.8507818579570614 and parameters: {'n_estimators': 333, 'max_depth': 7, 'learning_rate': 0.22341679412137588, 'subsample': 0.7974049590235863, 'reg_alpha': 0.0088156747280986}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:19:36,755] Trial 44 finished with value: 0.8478123243442545 and parameters: {'n_estimators': 287, 'max_depth': 7, 'learning_rate': 0.16286795968171683, 'subsample': 0.7781237928031552, 'reg_alpha': 0.03653595247220757}. Best is trial 19 with value: 0.8521211829428211.
# [I 2025-04-05 23:20:52,462] Trial 45 finished with value: 0.8531056977364799 and parameters: {'n_estimators': 399, 'max_depth': 7, 'learning_rate': 0.2888178506417322, 'subsample': 0.8326507645367822, 'reg_alpha': 0.07380416863525069}. Best is trial 45 with value: 0.8531056977364799.
# [I 2025-04-05 23:22:07,511] Trial 46 finished with value: 0.8465017702344633 and parameters: {'n_estimators': 384, 'max_depth': 7, 'learning_rate': 0.10404027029589746, 'subsample': 0.8597405578495834, 'reg_alpha': 0.19843155880916416}. Best is trial 45 with value: 0.8531056977364799.
# [I 2025-04-05 23:23:13,950] Trial 47 finished with value: 0.847764378902391 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.21670090132103006, 'subsample': 0.7243244523404374, 'reg_alpha': 0.09460038160878462}. Best is trial 45 with value: 0.8531056977364799.
# [I 2025-04-05 23:24:23,028] Trial 48 finished with value: 0.8489374869415918 and parameters: {'n_estimators': 357, 'max_depth': 7, 'learning_rate': 0.14690284236002163, 'subsample': 0.898414317302726, 'reg_alpha': 0.7665320604174566}. Best is trial 45 with value: 0.8531056977364799.
# [I 2025-04-05 23:25:21,313] Trial 49 finished with value: 0.7942105261748854 and parameters: {'n_estimators': 340, 'max_depth': 6, 'learning_rate': 0.009561546018418809, 'subsample': 0.6674593774817983, 'reg_alpha': 0.07591778252126079}. Best is trial 45 with value: 0.8531056977364799.

# %%
print("Best hyperparameters:", study.best_params)
print("Best accuracy:", study.best_value)
# Out:
# Best hyperparameters: {'n_estimators': 399, 'max_depth': 7, 'learning_rate': 0.2888178506417322, 'subsample': 0.8326507645367822, 'reg_alpha': 0.07380416863525069}
# Best accuracy: 0.8531056977364799

# %%
best_xgb_model = XGBClassifier(random_state=22, **study.best_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [135], in <cell line: 1>()
# ----> 1 best_xgb_model =url_dfGBClassifier(random_state=22, **study.best_params)
#
# NameError: name 'url_dfGBClassifier' is not defined

# %%
best_xgb_model.fit(url_df_train, y_train)

# %%
best_xgb_pred = best_xgb_model.predict(url_df_test)

# %%
print(accuracy_score(y_test, best_xgb_pred))
